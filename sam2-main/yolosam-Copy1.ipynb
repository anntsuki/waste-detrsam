# %%
# rt-detr r18 sam原版
# !python  -u visualizep.py --rtdetr_weights  E:\stv\ml\paper\RTDETR-pl\results\polyp\train\rtdetr-r18.yaml_train_120\weights\best.pt  --sam-config sam2.1_hiera_l.yaml  --sam-checkpoint checkpoints/sam2.1_hiera_large.pt  --output_dir ./ablation_study/ --conf-threshold 0.25
# Out:
# 本次所有数据集的评估结果将保存到主目录: ./ablation_study/eval_run_20250803_122840
# 正在加载 RT-DETR 模型: E:\stv\ml\paper\RTDETR-pl\results\polyp\train\rtdetr-r18.yaml_train_120\weights\best.pt
# 正在加载 SAM2 模型: checkpoints/sam2.1_hiera_large.pt
# 检测到以 'model:' 为根的推理配置文件...
# 正在创建模型实例...
#
# ...
# 开始评估数据集: CVC-300
# ...
# 数据集 'CVC-300' 的详细报告已保存到: ./ablation_study/eval_run_20250803_122840\CVC-300\CVC-300_evaluation_summary.txt
#
# ...
# 开始评估数据集: CVC-ColonDB
# ...
# 数据集 'CVC-ColonDB' 的详细报告已保存到: ./ablation_study/eval_run_20250803_122840\CVC-ColonDB\CVC-ColonDB_evaluation_summary.txt
#
# ...
# 开始评估数据集: ETIS-LaribPolypDB
# ...
# 数据集 'ETIS-LaribPolypDB' 的详细报告已保存到: ./ablation_study/eval_run_20250803_122840\ETIS-LaribPolypDB\ETIS-LaribPolypDB_evaluation_summary.txt
#
# ...
# 开始评估数据集: mix
# ...
# 数据集 'mix' 的详细报告已保存到: ./ablation_study/eval_run_20250803_122840\mix\mix_evaluation_summary.txt
#
#
# ##############################
# ### 所有数据集评估完成，生成总览报告 ###
# ##############################
#
# ...

# %%
# rt-detr r18 sam原版
# !python  -u visualizep.py --rtdetr_weights  E:\stv\ml\paper\RTDETR-pl\results\polyp\train\rtdetr-Conv3XCNCSPELAN_DPB_CGBD.yaml_train\weights\best.pt  --sam-config sam2.1_hiera_l.yaml  --sam-checkpoint checkpoints/sam2.1_hiera_large.pt  --output_dir ./ablation_study/ --conf-threshold 0.25
# Out:
# 本次所有数据集的评估结果将保存到主目录: ./ablation_study/eval_run_20250803_125323
# 正在加载 RT-DETR 模型: E:\stv\ml\paper\RTDETR-pl\results\polyp\train\rtdetr-Conv3XCNCSPELAN_DPB_CGBD.yaml_train\weights\best.pt
# 正在加载 SAM2 模型: checkpoints/sam2.1_hiera_large.pt
# 检测到以 'model:' 为根的推理配置文件...
# 正在创建模型实例...
#
# ...
# 开始评估数据集: CVC-300
# ...
# 数据集 'CVC-300' 的详细报告已保存到: ./ablation_study/eval_run_20250803_125323\CVC-300\CVC-300_evaluation_summary.txt
#
# ...
# 开始评估数据集: CVC-ColonDB
# ...
# 数据集 'CVC-ColonDB' 的详细报告已保存到: ./ablation_study/eval_run_20250803_125323\CVC-ColonDB\CVC-ColonDB_evaluation_summary.txt
#
# ...
# 开始评估数据集: ETIS-LaribPolypDB
# ...
# 数据集 'ETIS-LaribPolypDB' 的详细报告已保存到: ./ablation_study/eval_run_20250803_125323\ETIS-LaribPolypDB\ETIS-LaribPolypDB_evaluation_summary.txt
#
# ...
# 开始评估数据集: mix
# ...
# 数据集 'mix' 的详细报告已保存到: ./ablation_study/eval_run_20250803_125323\mix\mix_evaluation_summary.txt
#
#
# ##############################
# ### 所有数据集评估完成，生成总览报告 ###
# ##############################
#
# ...

# %%
# rt-detr r18 sam原版
# !python  -u visualizep.py --rtdetr_weights  E:\stv\ml\paper\RTDETR-pl\results\polyp\train\rtdetr-r18.yaml_train_120\weights\best.pt  --sam-config sam2.1_hiera_l.yaml  --sam-checkpoint checkpoints/sam2.1_hiera_large.pt  --output_dir ./ablation_study/ --conf-threshold 0.25
# Out:
# 本次所有数据集的评估结果将保存到主目录: ./ablation_study/eval_run_20250803_171758
# ...
# 正在评估 CVC-ClinicDB: 100%|██████████| 62/62 [00:50<00:00,  1.23it/s]
#
# ...
# 正在评估 Kvasir: 100%|██████████| 100/100 [01:25<00:00,  1.16it/s]
# 正在加载 RT-DETR 模型: E:\stv\ml\paper\RTDETR-pl\results\polyp\train\rtdetr-r18.yaml_train_120\weights\best.pt
# 正在加载 SAM2 模型: checkpoints/sam2.1_hiera_large.pt
# 检测到以 'model:' 为根的推理配置文件...
# 正在创建模型实例...
#
# ...
# 开始评估数据集: CVC-ClinicDB
# ...
# 数据集 'CVC-ClinicDB' 的详细报告已保存到: ./ablation_study/eval_run_20250803_171758\CVC-ClinicDB\CVC-ClinicDB_evaluation_summary.txt
#
# ...
# 开始评估数据集: Kvasir
# ...
# 数据集 'Kvasir' 的详细报告已保存到: ./ablation_study/eval_run_20250803_171758\Kvasir\Kvasir_evaluation_summary.txt
#
#
# ##############################
# ### 所有数据集评估完成，生成总览报告 ###
# ##############################
#
# +------------------+--------+--------+-----------+--------+-----------+-----------+
# | 数据集 (Dataset) |  Iou   |  Dice  | Precision | Recall | S Measure | E Measure |
# ...

# %%
# !python  -u visualizep.py --rtdetr_weights  E:\stv\ml\paper\RTDETR-pl\results\polyp\train\rtdetr-Conv3XCNCSPELAN_DPB_CGBD.yaml_train\weights\best.pt  --sam-config sam2.1_hiera_l.yaml  --sam-checkpoint checkpoints/sam2.1_hiera_large.pt  --output_dir ./ablation_study/ --conf-threshold 0.25
# Out:
# 本次所有数据集的评估结果将保存到主目录: ./ablation_study/eval_run_20250803_172038
# 正在加载 RT-DETR 模型: E:\stv\ml\paper\RTDETR-pl\results\polyp\train\rtdetr-Conv3XCNCSPELAN_DPB_CGBD.yaml_train\weights\best.pt
# 正在加载 SAM2 模型: checkpoints/sam2.1_hiera_large.pt
# 检测到以 'model:' 为根的推理配置文件...
# 正在创建模型实例...
#
# ...
# 开始评估数据集: CVC-ClinicDB
# ...
# 数据集 'CVC-ClinicDB' 的详细报告已保存到: ./ablation_study/eval_run_20250803_172038\CVC-ClinicDB\CVC-ClinicDB_evaluation_summary.txt
#
# ...
# 开始评估数据集: Kvasir
# ...
# 数据集 'Kvasir' 的详细报告已保存到: ./ablation_study/eval_run_20250803_172038\Kvasir\Kvasir_evaluation_summary.txt
#
#
# ##############################
# ### 所有数据集评估完成，生成总览报告 ###
# ##############################
#
# +------------------+--------+--------+-----------+--------+-----------+-----------+
# | 数据集 (Dataset) |  Iou   |  Dice  | Precision | Recall | S Measure | E Measure |
# +------------------+--------+--------+-----------+--------+-----------+-----------+
# |   CVC-ClinicDB   | 0.7914 | 0.8558 |   0.9208  | 0.8282 |   0.8589  |   0.2982  |
# ...

# %%
# !python  -u visualizep.py --rtdetr_weights  E:\stv\ml\paper\RTDETR-pl\results\polyp\train\rtdetr-Conv3XCNCSPELAN_DPB_CGBD.yaml_train\weights\best.pt  --sam-config sam2.1_hiera_l.yaml  --sam-checkpoint checkpoints/sam2.1_hiera_large.pt  --output_dir ./ablation_study/ --conf-threshold 0.25
# Out:
# ^C
