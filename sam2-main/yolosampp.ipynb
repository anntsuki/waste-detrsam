# %%
# yolo11原版加sam2.1
# !python E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\visualize.py --yolo_weights E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\runs\exp20\best.pt  --image_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\img\test --sam-config E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2\configs\sam2.1\sam2.1_hiera_b+.yaml  --gt_txt_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\masks\test --output_dir ./ablation_study/  --conf-threshold 0.25 --sam-checkpoint E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\checkpoints\sam2.1_hiera_base_plus.pt
# Out:
# 本次運行的所有結果將保存到: ./ablation_study/eval_baseline_20250814_093538
# 检测到以 'model:' 为根的推理配置文件...
# 正在创建模型实例...
# 平均 Iou: 0.7844
# 平均 Dice: 0.8585
# 平均 Precision: 0.9223
# 平均 Recall: 0.8351
# 平均 S Measure: 0.8500
# 平均 E Measure: 0.2990
#
# 評估報告已保存到: ./ablation_study/eval_baseline_20250814_093538\evaluation_results.txt
# 每張圖片的詳細指標已保存到: ./ablation_study/eval_baseline_20250814_093538\per_image_results.csv
# YOLO檢測框可視化圖已保存到: ./ablation_study/eval_baseline_20250814_093538\detection_results
# 最終分割可視化圖已保存到: ./ablation_study/eval_baseline_20250814_093538\segmentation_results
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# ...

# %%
# yolo11原版 微调
# !python E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\visualize.py --yolo_weights E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\runs\exp20\best.pt  --image_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\img\test --sam-config E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\config.yaml  --gt_txt_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\masks\test --output_dir ./ablation_study/ --conf-threshold 0.25 --sam-checkpoint E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\checkpoints\checkpoint_50.pt
# Out:
# 本次運行的所有結果將保存到: ./ablation_study/eval_baseline_20250814_092606
# 检测到训练配置文件，正在从 'trainer.model' 加载模型结构...
# 正在创建模型实例...
# 平均 Iou: 0.8181
# 平均 Dice: 0.8871
# 平均 Precision: 0.9659
# 平均 Recall: 0.8413
# 平均 S Measure: 0.8677
# 平均 E Measure: 0.2997
#
# 評估報告已保存到: ./ablation_study/eval_baseline_20250814_092606\evaluation_results.txt
# 每張圖片的詳細指標已保存到: ./ablation_study/eval_baseline_20250814_092606\per_image_results.csv
# YOLO檢測框可視化圖已保存到: ./ablation_study/eval_baseline_20250814_092606\detection_results
# 最終分割可視化圖已保存到: ./ablation_study/eval_baseline_20250814_092606\segmentation_results
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# ...

# %%
# exp20 yolo11 原版 sam微调 rectify
# !python E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\visualizep.py --rectify --yolo_weights  E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\runs\exp20\best.pt  --image_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\img\test --sam-config E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\config.yaml  --gt_txt_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\masks\test --output_dir ./ablation_study/ --conf-threshold 0.25 --sam-checkpoint E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\checkpoints\checkpoint_50.pt
# Out:
# 本次運行的所有結果將保存到: ./ablation_study/eval_rectified_20250814_174350
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\mmcv\__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
# ...

# %%
# 加dynamic exp20 yolo11动态卷积  sam原版
# !python E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\visualizep.py  --yolo_weights  E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\runs\exp3\best.pt  --image_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\img\test --sam-config E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2\configs\sam2.1\sam2.1_hiera_b+.yaml  --gt_txt_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\masks\test --output_dir ./ablation_study/  --conf-threshold 0.25 --sam-checkpoint E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\checkpoints\sam2.1_hiera_base_plus.pt
# Out:
# 本次運行的所有結果將保存到: ./ablation_study/eval_baseline_20250814_150839
# 模式: 基礎模式 (Baseline Mode: ON)
# 检测到以 'model:' 为根的推理配置文件...
# 正在创建模型实例...
# 平均 Iou: 0.7829
# 平均 Dice: 0.8526
# 平均 Precision: 0.9292
# 平均 Recall: 0.8311
# 平均 S Measure: 0.8526
# 平均 E Measure: 0.2979
#
# 評估報告已保存到: ./ablation_study/eval_baseline_20250814_150839\evaluation_results.txt
# 每張圖片的詳細指標已保存到: ./ablation_study/eval_baseline_20250814_150839\per_image_results.csv
# YOLO檢測框可視化圖已保存到: ./ablation_study/eval_baseline_20250814_150839\detection_results
# 最終分割可視化圖已保存到: ./ablation_study/eval_baseline_20250814_150839\segmentation_results
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# ...

# %%
# 加dynamic exp20 yolo11动态卷积  sam微调
# !python E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\visualizep.py  --yolo_weights  E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\runs\exp3\best.pt  --image_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\tdataset\cdeddataseg\img\test --sam-config E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\config.yaml  --gt_txt_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\masks\tes --output_dir ./ablation_study/ --conf-threshold 0.25 --sam-checkpoint E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\checkpoints\checkpoint_50.pt
# Out:
# 本次運行的所有結果將保存到: ./ablation_study/eval_baseline_20250814_095051
# 模式: 基礎模式 (Baseline Mode: ON)
# 检测到训练配置文件，正在从 'trainer.model' 加载模型结构...
# 正在创建模型实例...
# 平均 Iou: 0.7939
# 平均 Dice: 0.8637
# 平均 Precision: 0.9650
# 平均 Recall: 0.8198
# 平均 S Measure: 0.8562
# 平均 E Measure: 0.2975
#
# 評估報告已保存到: ./ablation_study/eval_baseline_20250814_095051\evaluation_results.txt
# 每張圖片的詳細指標已保存到: ./ablation_study/eval_baseline_20250814_095051\per_image_results.csv
# YOLO檢測框可視化圖已保存到: ./ablation_study/eval_baseline_20250814_095051\detection_results
# 最終分割可視化圖已保存到: ./ablation_study/eval_baseline_20250814_095051\segmentation_results
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# ...

# %%
# 加dynamic exp20 yolo11动态卷积  sam微调 rectify
# !python E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\visualizep.py --rectify --yolo_weights  E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\runs\exp3\best.pt  --image_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\img\test --sam-config E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\config.yaml  --gt_txt_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\masks\test --output_dir ./ablation_study/ --conf-threshold 0.25 --sam-checkpoint E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\checkpoints\checkpoint_50.pt
# Out:
# 本次運行的所有結果將保存到: ./ablation_study/eval_rectified_20250814_175511
# 模式: 已啟用不確定性校正 (Uncertainty Rectification Mode: ON)
# 检测到训练配置文件，正在从 'trainer.model' 加载模型结构...
# 正在创建模型实例...
# 平均 Iou: 0.8138
# 平均 Dice: 0.8829
# 平均 Precision: 0.9694
# 平均 Recall: 0.8378
# 平均 S Measure: 0.8716
# 平均 E Measure: 0.2987
#
# 評估報告已保存到: ./ablation_study/eval_rectified_20250814_175511\evaluation_results.txt
# 每張圖片的詳細指標已保存到: ./ablation_study/eval_rectified_20250814_175511\per_image_results.csv
# YOLO檢測框可視化圖已保存到: ./ablation_study/eval_rectified_20250814_175511\detection_results
# 最終分割可視化圖已保存到: ./ablation_study/eval_rectified_20250814_175511\segmentation_results
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# ...

# %%
# 加dynamic exp8 yolo11改2  sam微调
# !python E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\visualize.py  --yolo_weights  E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\runs\exp8\best.pt  --image_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\img\test --sam-config E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\config.yaml  --gt_txt_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\masks\test --output_dir ./ablation_study/ --conf-threshold 0.25 --sam-checkpoint E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\checkpoints\checkpoint_50.pt
# Out:
# 本次運行的所有結果將保存到: ./ablation_study/eval_baseline_20250813_233627
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\mmcv\__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
# ...

# %%
# 加dynamic exp21 yolo11 aux head  sam微调 rectify
# !python E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\visualizep.py --rectify --yolo_weights  E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\runs\exp21\best.pt  --image_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\img\test --sam-config E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\config.yaml  --gt_txt_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\masks\test --output_dir ./ablation_study/ --conf-threshold 0.25 --sam-checkpoint E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\checkpoints\checkpoint_50.pt
# Out:
# 本次運行的所有結果將保存到: ./ablation_study/eval_rectified_20250814_142941
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\mmcv\__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
# ...

# %%
# 加dynamic exp21 yolo11 aux head  sam微调 rectify
# !python E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\visualizep.py --rectify --yolo_weights  E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\runs\exp23\best.pt  --image_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\img\test --sam-config E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\config.yaml  --gt_txt_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\masks\test --output_dir ./ablation_study/ --conf-threshold 0.25 --sam-checkpoint E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\checkpoints\checkpoint_50.pt
# Out:
# 本次運行的所有結果將保存到: ./ablation_study/eval_rectified_20250814_173427
# 模式: 已啟用不確定性校正 (Uncertainty Rectification Mode: ON)
# 检测到训练配置文件，正在从 'trainer.model' 加载模型结构...
# 正在创建模型实例...
# 平均 Iou: 0.7633
# 平均 Dice: 0.8409
# 平均 Precision: 0.9673
# 平均 Recall: 0.7882
# 平均 S Measure: 0.8358
# 平均 E Measure: 0.2959
#
# 評估報告已保存到: ./ablation_study/eval_rectified_20250814_173427\evaluation_results.txt
# 每張圖片的詳細指標已保存到: ./ablation_study/eval_rectified_20250814_173427\per_image_results.csv
# YOLO檢測框可視化圖已保存到: ./ablation_study/eval_rectified_20250814_173427\detection_results
# 最終分割可視化圖已保存到: ./ablation_study/eval_rectified_20250814_173427\segmentation_results
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# ...

# %%
# 加dynamic exp21 yolo11 aux head  sam微调 rectify
# !python E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\visualizep.py --rectify --yolo_weights  E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\runs\exp24\best.pt  --image_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\img\test --sam-config E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\config.yaml  --gt_txt_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\masks\test --output_dir ./ablation_study/ --conf-threshold 0.25 --sam-checkpoint E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\checkpoints\checkpoint_50.pt
# Out:
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\mmcv\__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
# ...

# %%
# yolo11原版加sam2.1
# !python E:\stv\ml\paper\RTDETR-pl\sam2-main\visualizeppp.py --yolo_weights E:\stv\ml\paper\RTDETR-pl\runs\exp\best.pt  --image_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\img\test --sam-config E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2\configs\sam2.1\sam2.1_hiera_b+.yaml  --gt_txt_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\masks\test --output_dir ./ablation_study/  --conf-threshold 0.25 --sam-checkpoint E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\checkpoints\sam2.1_hiera_base_plus.pt
# Out:
# 本次運行的所有結果將保存到: ./ablation_study/eval_baseline_20250814_224518
# 模式: 基礎模式 (Baseline Mode: ON)
# 检测到以 'model:' 为根的推理配置文件...
# 正在创建模型实例...
# 平均 Iou: 0.7797
# 平均 Dice: 0.8436
# 平均 Precision: 0.8725
# 平均 Recall: 0.8723
# 平均 S Measure: 0.8553
# 平均 E Measure: 0.3010
#
# 評估報告已保存到: ./ablation_study/eval_baseline_20250814_224518\evaluation_results.txt
# 每張圖片的詳細指標已保存到: ./ablation_study/eval_baseline_20250814_224518\per_image_results.csv
# YOLO檢測框可視化圖已保存到: ./ablation_study/eval_baseline_20250814_224518\detection_results
# 最終分割可視化圖已保存到: ./ablation_study/eval_baseline_20250814_224518\segmentation_results
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# ...

# %%
# rt detr 原版 加sam原版 sam微调
# !python E:\stv\ml\paper\RTDETR-pl\sam2-main\visualizeppp.py  --yolo_weights  E:\stv\ml\paper\RTDETR-pl\runs\exp\best.pt  --image_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\img\test --sam-config E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\config.yaml  --gt_txt_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\masks\test --output_dir ./ablation_study/ --conf-threshold 0.25 --sam-checkpoint E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\checkpoints\checkpoint_50.pt
# Out:
# 本次運行的所有結果將保存到: ./ablation_study/eval_baseline_20250814_225523
# 模式: 基礎模式 (Baseline Mode: ON)
# 检测到训练配置文件，正在从 'trainer.model' 加载模型结构...
# 正在创建模型实例...
# 平均 Iou: 0.8466
# 平均 Dice: 0.9062
# 平均 Precision: 0.9579
# 平均 Recall: 0.8789
# 平均 S Measure: 0.8894
# 平均 E Measure: 0.3015
#
# 評估報告已保存到: ./ablation_study/eval_baseline_20250814_225523\evaluation_results.txt
# 每張圖片的詳細指標已保存到: ./ablation_study/eval_baseline_20250814_225523\per_image_results.csv
# YOLO檢測框可視化圖已保存到: ./ablation_study/eval_baseline_20250814_225523\detection_results
# 最終分割可視化圖已保存到: ./ablation_study/eval_baseline_20250814_225523\segmentation_results
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# ...

# %%
# rt detr 原版 加sam原版 sam微调 rectify
# !python E:\stv\ml\paper\RTDETR-pl\sam2-main\visualizeppp.py --rectify --yolo_weights  E:\stv\ml\paper\RTDETR-pl\runs\exp\best.pt  --image_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\img\test --sam-config E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\config.yaml  --gt_txt_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\masks\test --output_dir ./ablation_study/ --conf-threshold 0.25 --sam-checkpoint E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\checkpoints\checkpoint_50.pt
# Out:
# 本次運行的所有結果將保存到: ./ablation_study/eval_rectified_20250814_202246
# 模式: 已啟用不確定性校正 (Uncertainty Rectification Mode: ON)
# 检测到训练配置文件，正在从 'trainer.model' 加载模型结构...
# 正在创建模型实例...
# 平均 Iou: 0.8640
# 平均 Dice: 0.9209
# 平均 Precision: 0.9673
# 平均 Recall: 0.8918
# 平均 S Measure: 0.9024
# 平均 E Measure: 0.3022
#
# 評估報告已保存到: ./ablation_study/eval_rectified_20250814_202246\evaluation_results.txt
# 每張圖片的詳細指標已保存到: ./ablation_study/eval_rectified_20250814_202246\per_image_results.csv
# YOLO檢測框可視化圖已保存到: ./ablation_study/eval_rectified_20250814_202246\detection_results
# 最終分割可視化圖已保存到: ./ablation_study/eval_rectified_20250814_202246\segmentation_results
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# ...

# %%
# rt detr 动态卷积 加 sam微调 rectify
# !python E:\stv\ml\paper\RTDETR-pl\sam2-main\visualizeppp.py --rectify --yolo_weights  E:\stv\ml\paper\RTDETR-pl\runs\exp7\best.pt  --image_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\img\test --sam-config E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\config.yaml  --gt_txt_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\masks\test --output_dir ./ablation_study/ --conf-threshold 0.25 --sam-checkpoint E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\checkpoints\checkpoint_50.pt
# Out:
# 本次運行的所有結果將保存到: ./ablation_study/eval_rectified_20250814_221720
# 模式: 已啟用不確定性校正 (Uncertainty Rectification Mode: ON)
# 检测到训练配置文件，正在从 'trainer.model' 加载模型结构...
# 正在创建模型实例...
# 平均 Iou: 0.8697
# 平均 Dice: 0.9237
# 平均 Precision: 0.9480
# 平均 Recall: 0.9119
# 平均 S Measure: 0.9103
# 平均 E Measure: 0.3033
#
# 評估報告已保存到: ./ablation_study/eval_rectified_20250814_221720\evaluation_results.txt
# 每張圖片的詳細指標已保存到: ./ablation_study/eval_rectified_20250814_221720\per_image_results.csv
# YOLO檢測框可視化圖已保存到: ./ablation_study/eval_rectified_20250814_221720\detection_results
# 最終分割可視化圖已保存到: ./ablation_study/eval_rectified_20250814_221720\segmentation_results
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# ...

# %%
# rt detr 动态卷积 加 sam微调 rectify
# !python E:\stv\ml\paper\RTDETR-pl\sam2-main\visualizeppp.py --rectify --yolo_weights  E:\stv\ml\paper\RTDETR-pl\runs\exp8\best.pt  --image_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\img\test --sam-config E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\config.yaml  --gt_txt_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\masks\test --output_dir ./ablation_study/ --conf-threshold 0.25 --sam-checkpoint E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\checkpoints\checkpoint_50.pt
# Out:
# 本次運行的所有結果將保存到: ./ablation_study/eval_rectified_20250814_232427
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# ...

# %%
# rt detr 动态卷积 加 sam微调 rectify
# !python E:\stv\ml\paper\RTDETR-pl\sam2-main\visualizeppp.py --rectify --yolo_weights  E:\stv\ml\paper\RTDETR-pl\runs\exp10\best.pt  --image_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\img\test --sam-config E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\config.yaml  --gt_txt_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\masks\test --output_dir ./ablation_study/ --conf-threshold 0.25 --sam-checkpoint E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\checkpoints\checkpoint_50.pt
# Out:
# 本次運行的所有結果將保存到: ./ablation_study/eval_rectified_20250815_102028
# 模式: 已啟用不確定性校正 (Uncertainty Rectification Mode: ON)
# 检测到训练配置文件，正在从 'trainer.model' 加载模型结构...
# 正在创建模型实例...
# 平均 Iou: 0.8767
# 平均 Dice: 0.9300
# 平均 Precision: 0.9554
# 平均 Recall: 0.9127
# 平均 S Measure: 0.9120
# 平均 E Measure: 0.3035
#
# 評估報告已保存到: ./ablation_study/eval_rectified_20250815_102028\evaluation_results.txt
# 每張圖片的詳細指標已保存到: ./ablation_study/eval_rectified_20250815_102028\per_image_results.csv
# YOLO檢測框可視化圖已保存到: ./ablation_study/eval_rectified_20250815_102028\detection_results
# 最終分割可視化圖已保存到: ./ablation_study/eval_rectified_20250815_102028\segmentation_results
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# ...

# %%
# rt detr 动态卷积 加 sam微调 rectify
# !python E:\stv\ml\paper\RTDETR-pl\sam2-main\visualizeppp.py --rectify --yolo_weights  E:\stv\ml\paper\RTDETR-pl\runs\exp11\best.pt  --image_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\img\test --sam-config E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\config.yaml  --gt_txt_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\masks\test --output_dir ./ablation_study/ --conf-threshold 0.25 --sam-checkpoint E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\checkpoints\checkpoint_50.pt
# Out:
# 本次運行的所有結果將保存到: ./ablation_study/eval_rectified_20250815_111615
# 模式: 已啟用不確定性校正 (Uncertainty Rectification Mode: ON)
# 检测到训练配置文件，正在从 'trainer.model' 加载模型结构...
# 正在创建模型实例...
# 平均 Iou: 0.8851
# 平均 Dice: 0.9360
# 平均 Precision: 0.9572
# 平均 Recall: 0.9226
# 平均 S Measure: 0.9185
# 平均 E Measure: 0.3039
#
# 評估報告已保存到: ./ablation_study/eval_rectified_20250815_111615\evaluation_results.txt
# 每張圖片的詳細指標已保存到: ./ablation_study/eval_rectified_20250815_111615\per_image_results.csv
# YOLO檢測框可視化圖已保存到: ./ablation_study/eval_rectified_20250815_111615\detection_results
# 最終分割可視化圖已保存到: ./ablation_study/eval_rectified_20250815_111615\segmentation_results
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# ...

# %%
# rt detr 动态卷积 加 sam微调 rectify
# !python E:\stv\ml\paper\RTDETR-pl\sam2-main\visualizeppp.py --rectify --yolo_weights  E:\stv\ml\paper\RTDETR-pl\runs\exp12\best.pt  --image_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\img\test --sam-config E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\config.yaml  --gt_txt_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\masks\test --output_dir ./ablation_study/ --conf-threshold 0.25 --sam-checkpoint E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\checkpoints\checkpoint_50.pt
# Out:
# 本次運行的所有結果將保存到: ./ablation_study/eval_rectified_20250815_133224
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# ...

# %%
# rt detr 动态卷积 加 sam微调 rectify
# !python E:\stv\ml\paper\RTDETR-pl\sam2-main\visualizeppp.py --rectify --yolo_weights  E:\stv\ml\paper\RTDETR-pl\runs\exp22\best.pt  --image_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\img\test --sam-config E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\config.yaml  --gt_txt_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\masks\test --output_dir ./ablation_study/ --conf-threshold 0.25 --sam-checkpoint E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\checkpoints\checkpoint_50.pt
# Out:
# 本次運行的所有結果將保存到: ./ablation_study/eval_rectified_20250815_222102
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# ...

# %%
# rt detr 动态卷积 加 sam微调 rectify
# !python E:\stv\ml\paper\RTDETR-pl\sam2-main\visualizeppp.py --rectify --yolo_weights  E:\stv\ml\paper\RTDETR-pl\runs\exp28\best.pt  --image_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\img\test --sam-config E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\config.yaml  --gt_txt_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\masks\test --output_dir ./ablation_study/ --conf-threshold 0.25 --sam-checkpoint E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\checkpoints\checkpoint_50.pt
# Out:
# 本次運行的所有結果將保存到: ./ablation_study/eval_rectified_20250816_093211
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# ...

# %%
# rt detr 动态卷积 加 sam微调 rectify
# !python E:\stv\ml\paper\RTDETR-pl\sam2-main\visualizeppp.py --rectify --yolo_weights  E:\stv\ml\paper\RTDETR-pl\runs\exp28\best.pt  --image_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\img\test --sam-config E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\config.yaml  --gt_txt_dir E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\dataset\cdeddataseg\masks\test --output_dir ./abla tion_study/ --conf-threshold 0.25 --sam-checkpoint E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\sam2-main\sam2_logs\sam2.1_hiera_b+_waste_finetune\checkpoints\checkpoint_50.pt
# Out:
# 本次運行的所有結果將保存到: ./ablation_study/eval_rectified_20250817_182722
# 模式: 已啟用不確定性校正 (Uncertainty Rectification Mode: ON)
# 检测到训练配置文件，正在从 'trainer.model' 加载模型结构...
# 正在创建模型实例...
# 平均 Iou: 0.8765
# 平均 Dice: 0.9224
# 平均 Precision: 0.9202
# 平均 Recall: 0.9504
# 平均 S Measure: 0.9131
# 平均 E Measure: 0.3065
#
# 評估報告已保存到: ./ablation_study/eval_rectified_20250817_182722\evaluation_results.txt
# 每張圖片的詳細指標已保存到: ./ablation_study/eval_rectified_20250817_182722\per_image_results.csv
# YOLO檢測框可視化圖已保存到: ./ablation_study/eval_rectified_20250817_182722\detection_results
# 最終分割可視化圖已保存到: ./ablation_study/eval_rectified_20250817_182722\segmentation_results
# D:\exe_c\anaconda3\envs\yolo11\lib\site-packages\timm\models\layers\__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# ...
