# %%
# rtdetr r18
# !python val-pl.py --weights E:\stv\ml\paper\RTDETR-pl\results\polyp\train\rtdetr-r18.yaml_train_120\weights\best.pt --model-type rtdetr
# Out:
# Ultralytics YOLOv8.0.201  Python-3.9.21 torch-2.1.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# rtdetr-r18 summary: 299 layers, 19873044 parameters, 0 gradients, 56.9 GFLOPs
#
# val: Scanning E:\stv\ml\paper\RTDETR-pl\results\DATESET\POLYP\test22\ETIS-LaribPolypDB\labels.cache... 196 images, 0 backgrounds, 0 corrupt: 100%|██████████| 196/196 [00:00<?, ?it/s]
# val: Scanning E:\stv\ml\paper\RTDETR-pl\results\DATESET\POLYP\test22\ETIS-LaribPolypDB\labels.cache... 196 images, 0 backgrounds, 0 corrupt: 100%|██████████| 196/196 [00:00<?, ?it/s]
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/25 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   4%|▍         | 1/25 [00:00<00:09,  2.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   8%|▊         | 2/25 [00:00<00:05,  3.95it/s]
# ...

# %%
# rtdetr r18p3
# !python val-pl.py --weights E:\stv\ml\paper\RTDETR-pl\results\polyp\train\rtdetr-Conv3XCNCSPELAN_DPB_CGBD.yaml_train\weights\best.pt --model-type rtdetr
# Out:
# Ultralytics YOLOv8.0.201  Python-3.9.21 torch-2.1.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# rtdetr-Conv3XCNCSPELAN_DPB_CGBD summary: 517 layers, 16493740 parameters, 0 gradients, 40.6 GFLOPs
#
# val: Scanning E:\stv\ml\paper\RTDETR-pl\results\DATESET\POLYP\test22\Kvasir\labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100%|██████████| 100/100 [00:00<?, ?it/s]
# val: Scanning E:\stv\ml\paper\RTDETR-pl\results\DATESET\POLYP\test22\Kvasir\labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100%|██████████| 100/100 [00:00<?, ?it/s]
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/13 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   8%|▊         | 1/13 [00:00<00:03,  3.09it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  15%|█▌        | 2/13 [00:00<00:02,  4.54it/s]
# ...

# %%
# rtdetr r18p3 final
# !python val-pl.py --weights E:\stv\ml\paper\RTDETR-pl\results\polyp\train\rtdetr-Conv3XCNCSPELAN_DPB_CGBD.yaml_train\weights\best.pt --model-type rtdetr
# Out:
# ...
# 正在加载 RTDETR 模型: E:\stv\ml\paper\RTDETR-pl\results\polyp\train\rtdetr-Conv3XCNCSPELAN_DPB_CGBD.yaml_train\weights\best.pt
# 开始使用 RTDETR 验证数据集: ETIS-LaribPolypDB (E:\stv\ml\paper\RTDETR-pl\results\DATESET\POLYP\ETIS-LaribPolypDB.yaml)
# ...
#
# +---------------------------------------------------------------------------------------------------------+
# |                                            模型信息 (best.pt)                                           |
# +--------+-----------+---------------+-------------+---------------+---------+-------------+--------------+
# | GFLOPs | 参数量(M) | 前处理/图(ms) | 推理/图(ms) | 后处理/图(ms) | FPS(总) | FPS(仅推理) | 模型大小(MB) |
# +--------+-----------+---------------+-------------+---------------+---------+-------------+--------------+
# |  40.6  |   16.49   |      0.43     |    14.19    |      0.38     |  66.68  |    70.48    |     65.4     |
# +--------+-----------+---------------+-------------+---------------+---------+-------------+--------------+
# ...

# %%
# rtdetr r18
# !python val-pl.py --weights E:\stv\ml\paper\RTDETR-pl\results\polyp\train\rtdetr-r18.yaml_train_120\weights\best.pt --model-type rtdetr
# Out:
# ...
# 正在加载 RTDETR 模型: E:\stv\ml\paper\RTDETR-pl\results\polyp\train\rtdetr-r18.yaml_train_120\weights\best.pt
# 开始使用 RTDETR 验证数据集: ETIS-LaribPolypDB (E:\stv\ml\paper\RTDETR-pl\results\DATESET\POLYP\ETIS-LaribPolypDB.yaml)
# ...
#
# +---------------------------------------------------------------------------------------------------------+
# |                                            模型信息 (best.pt)                                           |
# +--------+-----------+---------------+-------------+---------------+---------+-------------+--------------+
# | GFLOPs | 参数量(M) | 前处理/图(ms) | 推理/图(ms) | 后处理/图(ms) | FPS(总) | FPS(仅推理) | 模型大小(MB) |
# +--------+-----------+---------------+-------------+---------------+---------+-------------+--------------+
# |  56.9  |   19.87   |      0.72     |    66.87    |      0.77     |  14.63  |    14.96    |     76.9     |
# +--------+-----------+---------------+-------------+---------------+---------+-------------+--------------+
# ...

# %%
# rtdetr r18p3 final tta
# !python val-pl.py --weights E:\stv\ml\paper\RTDETR-pl\results\polyp\train\rtdetr-Conv3XCNCSPELAN_DPB_CGBD.yaml_train\weights\best.pt --model-type rtdetr
# Out:
# ...
# 正在加载 RTDETR 模型: E:\stv\ml\paper\RTDETR-pl\results\polyp\train\rtdetr-Conv3XCNCSPELAN_DPB_CGBD.yaml_train\weights\best.pt
# 开始使用 RTDETR 验证数据集: ETIS-LaribPolypDB (E:\stv\ml\paper\RTDETR-pl\results\DATESET\POLYP\ETIS-LaribPolypDB.yaml)
# ...
#
# +---------------------------------------------------------------------------------------------------------+
# |                                            模型信息 (best.pt)                                           |
# +--------+-----------+---------------+-------------+---------------+---------+-------------+--------------+
# | GFLOPs | 参数量(M) | 前处理/图(ms) | 推理/图(ms) | 后处理/图(ms) | FPS(总) | FPS(仅推理) | 模型大小(MB) |
# +--------+-----------+---------------+-------------+---------------+---------+-------------+--------------+
# |  40.6  |   16.49   |      0.42     |    14.45    |      0.35     |  65.70  |    69.19    |     65.4     |
# +--------+-----------+---------------+-------------+---------------+---------+-------------+--------------+
# ...

# %%
# rtdetr r18p3 final tta
# !python val-pl.py --weights E:\stv\ml\paper\RTDETR-pl\runs\exp\best.pt --model-type rtdetr
# Out:
# ...
# 正在加载 RTDETR 模型: E:\stv\ml\paper\RTDETR-pl\runs\exp\best.pt
# 开始使用 RTDETR 验证数据集: cdwdata (E:\stv\ml\paper\yolo11\ultralytics-yolo11-main\ultralytics\cfg\datasets\cdwdata.yaml)
# ...
#
# +---------------------------------------------------------------------------------------------------------+
# |                                            模型信息 (best.pt)                                           |
# +--------+-----------+---------------+-------------+---------------+---------+-------------+--------------+
# | GFLOPs | 参数量(M) | 前处理/图(ms) | 推理/图(ms) | 后处理/图(ms) | FPS(总) | FPS(仅推理) | 模型大小(MB) |
# +--------+-----------+---------------+-------------+---------------+---------+-------------+--------------+
# |  57.0  |   19.88   |      0.61     |    14.09    |      0.53     |  65.66  |    70.99    |     77.0     |
# +--------+-----------+---------------+-------------+---------------+---------+-------------+--------------+
# ...
